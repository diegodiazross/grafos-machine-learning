# %%
from neo4j import GraphDatabase

URI = "neo4j://localhost:7687"
USER = "neo4j"
PASSWORD = "12345678"
AUTH = (USER, PASSWORD)
driver = GraphDatabase.driver(URI, auth=AUTH)
driver.verify_connectivity()
print("Conexión exitosa")
# Out:
# Conexión exitosa

# %%
# crear una base de datos de grafos
query = """CREATE DATABASE grafos_ml IF NOT EXISTS;"""
resumen = driver.execute_query(query).summary()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 # crear una base de datos de grafos
#       2 query = """CREATE DATABASE grafos_ml IF NOT EXISTS;"""
# ----> 3 resumen = driver.execute_query(query).summary()
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/driver.py:946, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     942     raise ValueError(
#     943         f"Invalid routing control value: {routing_!r}"
#     944     )
#     945 with session._pipelined_begin:
# --> 946     return session._run_transaction(
#     947         access_mode,
#     948         TelemetryAPI.DRIVER,
#     949         work,
#     950         (query_str, parameters, result_transformer_),
#     951         {},
#     952     )
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/work/session.py:543, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     541 tx = self._transaction
#     542 try:
# --> 543     result = transaction_function(tx, *args, **kwargs)
#     544 except asyncio.CancelledError:
#     545     # if cancellation callback has not been called yet:
#     546     if self._transaction is not None:
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/driver.py:1298, in _work(tx, query, parameters, transformer)
#    1292 def _work(
#    1293     tx: ManagedTransaction,
#    1294     query: t.LiteralString,
#    1295     parameters: dict[str, t.Any],
#    1296     transformer: t.Callable[[Result], t.Union[_T]],
#    1297 ) -> _T:
# -> 1298     res = tx.run(query, parameters)
#    1299     return transformer(res)
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/work/transaction.py:201, in TransactionBase.run(self, query, parameters, **kwparameters)
#     198 self._results.append(result)
#     200 parameters = dict(parameters or {}, **kwparameters)
# --> 201 result._tx_ready_run(query, parameters)
#     203 return result
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/work/result.py:178, in Result._tx_ready_run(self, query, parameters)
#     174 def _tx_ready_run(self, query, parameters):
#     175     # BEGIN+RUN does not carry any extra on the RUN message.
#     176     # BEGIN {extra}
#     177     # RUN "query" {parameters} {extra}
# --> 178     self._run(query, parameters, None, None, None, None, None, None)
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/work/result.py:237, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     235 self._pull()
#     236 self._connection.send_all()
# --> 237 self._attach()
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/work/result.py:439, in Result._attach(self)
#     437 if self._exhausted is False:
#     438     while self._attached is False:
# --> 439         self._connection.fetch_message()
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:192, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     190 def inner(*args, **kwargs):
#     191     try:
# --> 192         func(*args, **kwargs)
#     193     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     194         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:866, in Bolt.fetch_message(self)
#     862 # Receive exactly one message
#     863 tag, fields = self.inbox.pop(
#     864     hydration_hooks=self.responses[0].hydration_hooks
#     865 )
# --> 866 res = self._process_message(tag, fields)
#     867 self.idle_since = monotonic()
#     868 return res
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_bolt6.py:548, in Bolt6x0._process_message(self, tag, fields)
#     546 self._enrich_error_diagnostic_record(summary_metadata)
#     547 try:
# --> 548     response.on_failure(summary_metadata or {})
#     549 except (ServiceUnavailable, DatabaseUnavailable):
#     550     if self.pool:
#
# File ~/proyectos/portafolio/grafos-machine-learning/.venv/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:262, in Response.on_failure(self, metadata)
#     260 handler = self.handlers.get("on_summary")
#     261 Util.callback(handler)
# --> 262 raise self._hydrate_error(metadata)
#
# ClientError: {neo4j_code: Neo.ClientError.Statement.UnsupportedAdministrationCommand} {message: Unsupported administration command: CREATE DATABASE grafos_ml IF NOT EXISTS;} {gql_status: 51N27} {gql_status_description: error: system configuration or operation exception - not supported in this edition. 'CREATE DATABASE' is not supported in community edition.}
